# %%
import datetime
import time
from collections import defaultdict
import pandas as pd
from time import mktime

import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy

stock_tickers = [
    'AMZN',
    'GOOGL',
    'MSFT',
    'ROKU',
    'NVDA',
    'CROX'
]

string_formatted_ticker_list = " ".join(stock_tickers)

data = yf.download(['SPY', 'AMZN', 'GOOGL', 'MSFT', 'NVDA', 'PYPL', 'HUBS', 'CROX', 'NKE', 'ADBE', 'BLK', 'TWTR', 'QCOM', 'FB',
                   'TGT', 'AAPL', 'EBAY', 'CRWD', 'CLF', 'NFLX', 'LB', 'LEVI', 'STLD', 'NET', 'VUG', 'INTU', 'SBUX', 'AZN', 'ASAN', 'MS','CMG',
                   'IT', 'MCO'], start="2021-01-01", end="2021-07-13")
df = data['Close']
df
# Out:
# [*********************100%***********************]  33 of 33 completed
#                   AAPL        ADBE         AMZN       ASAN        AZN  \
# Date
# 2021-01-04  129.410004  485.339996  3186.629883  29.000000  50.520000
# 2021-01-05  131.009995  485.690002  3218.510010  28.549999  50.700001
# 2021-01-06  126.599998  466.309998  3138.379883  28.030001  50.910000
# 2021-01-07  130.919998  477.739990  3162.159912  28.900000  50.189999
# 2021-01-08  132.050003  485.100006  3182.699951  31.580000  50.860001
# ...                ...         ...          ...        ...        ...
# 2021-07-06  142.020004  596.900024  3675.739990  68.510002  59.900002
# 2021-07-07  144.570007  605.770020  3696.580078  66.879997  59.759998
# 2021-07-08  143.240005  605.950012  3731.409912  66.389999  59.259998
# 2021-07-09  145.110001  604.500000  3719.340088  68.110001  59.630001
# 2021-07-12  144.500000  600.200012  3718.550049  66.940002  60.500000
#
# ...

# %%
# Calculate expected returns and sample covariance
mu = expected_returns.mean_historical_return(df)
S = risk_models.sample_cov(df)

# Optimize for maximal Sharpe ratio
ef = EfficientFrontier(mu, S)
raw_weights = ef.max_sharpe()
cleaned_weights = ef.clean_weights()
ef.save_weights_to_file("weights.csv")  # saves to file
print(cleaned_weights)
ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('AAPL', 0.0), ('ADBE', 0.0), ('AMZN', 0.0), ('ASAN', 0.27182), ('AZN', 0.0), ('BLK', 0.0), ('CLF', 0.0), ('CMG', 0.0), ('CROX', 0.0), ('CRWD', 0.0), ('EBAY', 0.0), ('FB', 0.07737), ('GOOGL', 0.0), ('HUBS', 0.0), ('INTU', 0.0), ('IT', 0.22818), ('LB', 0.17966), ('LEVI', 0.11916), ('MCO', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NET', 0.0), ('NFLX', 0.0), ('NKE', 0.0), ('NVDA', 0.0), ('PYPL', 0.0), ('QCOM', 0.0), ('SBUX', 0.0), ('SPY', 0.0), ('STLD', 0.1238), ('TGT', 0.0), ('TWTR', 0.0), ('VUG', 0.0)])
# Expected annual return: 233.7%
# Annual volatility: 25.2%
# Sharpe Ratio: 9.21
# (2.336920310504889, 0.25151477547341544, 9.211865609659908)
